# %% [markdown]
# # eCommerce Customer Analysis - Exploratory Data Analysis (EDA)
#
# This notebook performs comprehensive exploratory data analysis on the eCommerce customer dataset to understand customer spending patterns and identify key features for predicting yearly spending.
#
# ## Objectives:
# - Analyze customer demographic and behavioral patterns
# - Identify key factors influencing yearly spending
# - Prepare data insights for regression modeling
# - Visualize relationships between features and target variable
#
# ---

# %% [markdown]
# ## 1. Import Required Libraries
#
# Import all necessary libraries for data analysis, visualization, and logging.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# Import custom modules
import sys
import os
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('__file__'))))

from src.exception import CustomException
from src.logger import logging

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Getting Data

# %%
df = pd.read_csv('../data/ecommerce_customer.csv')

# %%
df.head()  # Display the first few rows of the dataset
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.tail()  # Display the last few rows of the dataset
# Out:
#                             Email  \
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address         Avatar  \
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...            Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320  PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...       Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...           Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...    DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# ...

# %% [markdown]
# ## Dropping Unnecesary Columns

# %%
df = df.drop(columns=['Email', 'Address', 'Avatar'])  # Drop unnecessary columns

# %%
df.shape
# Out:
# (500, 5)

# %% [markdown]
# ## Checking Missing Values

# %%
df.isna().sum()  # Check for missing values
# Out:
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
df.duplicated().sum()  # Check Duplicated Rows
# Out:
# np.int64(0)

# %%
df.info()  # Get a concise summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Avg. Session Length   500 non-null    float64
#  1   Time on App           500 non-null    float64
#  2   Time on Website       500 non-null    float64
#  3   Length of Membership  500 non-null    float64
#  4   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB

# %%
df.nunique()  # Get the number of unique values in each column
# Out:
# Avg. Session Length     500
# Time on App             500
# Time on Website         500
# Length of Membership    500
# Yearly Amount Spent     500
# dtype: int64

# %%
df.describe()  # Statistical summary of the dataset
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.pairplot(df)  # Pairplot to visualize relationships between variables

# %%
# Distribution of target variable (Yearly Amount Spent)
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(df['Yearly Amount Spent'], bins=30, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribution of Yearly Amount Spent')
plt.xlabel('Yearly Amount Spent ($)')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.boxplot(y=df['Yearly Amount Spent'], color='lightgreen')
plt.title('Box Plot of Yearly Amount Spent')
plt.ylabel('Yearly Amount Spent ($)')

plt.tight_layout()
plt.show()

# %%
# Feature distributions - all numerical variables
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Plot distributions for each feature
features = ['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']

for i, feature in enumerate(features):
    row = i // 2
    col = i % 2
    
    axes[row, col].hist(df[feature], bins=25, alpha=0.7, color='coral', edgecolor='black')
    axes[row, col].set_title(f'Distribution of {feature}')
    axes[row, col].set_xlabel(feature)
    axes[row, col].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📈 Correlation Analysis

# %%
# Correlation matrix heatmap
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()

# Create heatmap
sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap='coolwarm', 
            center=0,
            square=True,
            fmt='.3f',
            cbar_kws={"shrink": .8})

plt.title('Feature Correlation Matrix', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# Print strongest correlations with target variable
target_correlations = correlation_matrix['Yearly Amount Spent'].sort_values(ascending=False)
print("Correlations with Yearly Amount Spent:")
print(target_correlations)
# Out:
# Correlations with Yearly Amount Spent:
# Yearly Amount Spent     1.000000
# Length of Membership    0.809084
# Time on App             0.499328
# Avg. Session Length     0.355088
# Time on Website        -0.002641
# Name: Yearly Amount Spent, dtype: float64

# %% [markdown]
# ## 📊 Scatter Plot Analysis

# %%
# Scatter plots - Features vs Target Variable
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

features = ['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']
colors = ['blue', 'green', 'red', 'purple']

for i, (feature, color) in enumerate(zip(features, colors)):
    row = i // 2
    col = i % 2
    
    axes[row, col].scatter(df[feature], df['Yearly Amount Spent'], 
                          alpha=0.6, color=color, s=50)
    
    # Add trend line
    z = np.polyfit(df[feature], df['Yearly Amount Spent'], 1)
    p = np.poly1d(z)
    axes[row, col].plot(df[feature], p(df[feature]), "r--", alpha=0.8, linewidth=2)
    
    axes[row, col].set_xlabel(feature)
    axes[row, col].set_ylabel('Yearly Amount Spent ($)')
    axes[row, col].set_title(f'{feature} vs Yearly Spending')
    axes[row, col].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 💼 Business Insights & Customer Segmentation

# %%
# Create customer spending segments for business analysis
df['Spending_Segment'] = pd.cut(df['Yearly Amount Spent'], 
                                bins=[0, 350, 500, 650, 1000], 
                                labels=['Low Spender', 'Medium Spender', 'High Spender', 'Premium Spender'])

# Segment analysis
plt.figure(figsize=(15, 5))

# Spending segment distribution
plt.subplot(1, 3, 1)
segment_counts = df['Spending_Segment'].value_counts()
plt.pie(segment_counts.values, labels=segment_counts.index, autopct='%1.1f%%', 
        colors=['lightcoral', 'lightskyblue', 'lightgreen', 'gold'])
plt.title('Customer Spending Segments')

# Average time on app by segment
plt.subplot(1, 3, 2)
sns.boxplot(data=df, x='Spending_Segment', y='Time on App', palette='viridis')
plt.xticks(rotation=45)
plt.title('Time on App by Spending Segment')

# Length of membership by segment
plt.subplot(1, 3, 3)
sns.boxplot(data=df, x='Spending_Segment', y='Length of Membership', palette='plasma')
plt.xticks(rotation=45)
plt.title('Membership Length by Spending Segment')

plt.tight_layout()
plt.show()

# Print segment statistics
print("\n=== Customer Segment Analysis ===")
for segment in df['Spending_Segment'].cat.categories:
    segment_data = df[df['Spending_Segment'] == segment]
    print(f"\n{segment} ({len(segment_data)} customers):")
    print(f"  Average Spending: ${segment_data['Yearly Amount Spent'].mean():.2f}")
    print(f"  Average App Time: {segment_data['Time on App'].mean():.1f} min")
    print(f"  Average Membership: {segment_data['Length of Membership'].mean():.1f} years")
# Out:
# === Customer Segment Analysis ===
#
# Low Spender (14 customers):
#   Average Spending: $305.23
#   Average App Time: 11.0 min
#   Average Membership: 1.5 years
#
# Medium Spender (237 customers):
#   Average Spending: $445.59
#   Average App Time: 11.8 min
#   Average Membership: 3.0 years
#
# High Spender (233 customers):
#   Average Spending: $552.42
#   Average App Time: 12.3 min
#   Average Membership: 4.1 years
#
# Premium Spender (16 customers):
#   Average Spending: $691.51
#   Average App Time: 13.2 min
#   Average Membership: 5.7 years

# %%
# Membership tenure analysis
plt.scatter(df['Length of Membership'], df['Yearly Amount Spent'], 
           c=df['Time on App'], cmap='viridis', s=60, alpha=0.6)
plt.colorbar(label='Time on App')

# %% [markdown]
# ## Insight Summary

# %% [markdown]
# Membership Retention: Longer-term customers are most valuable
# Mobile Strategy: App engagement drives revenue more than web
# Customer Lifecycle: Spending increases with membership maturity
# Engagement Quality: Session length matters for conversion
